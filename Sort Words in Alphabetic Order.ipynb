# %%
# Program to sort alphabetically the words form a string procided by the user

user_str = input("Enter a string: ")

# Breakdown the string into a list of words
words = [word.capitalize() for word in user_str.split()]

# Sort the list
words.sort()

# Display the sorted words

print("The sorted words are:")
for word in words:
    print(word)
# Out:
# Enter a string:  bruno miguel ricardo shallon denise valeria paulo cesar
# The sorted words are:
# Bruno
# Cesar
# Denise
# Miguel
# Paulo
# Ricardo
# Shallon
# Valeria
